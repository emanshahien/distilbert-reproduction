# %% [markdown]
# # Setup
# This notebook installs dependencies (optional) and performs quick environment checks.
# Use the workspace virtual environment or run `pip install -r requirements.txt` in a terminal.

# %%
# Check Python and torch
import sys
print('Python', sys.version)
import torch
print('torch', torch.__version__, 'cuda available:', torch.cuda.is_available())

# %% [markdown]
# ## Import other packages
#
# %pip install transformers datasets evaluate accelerate

# %%
# %pip install transformers datasets evaluate accelerate

# %%
# Verify all GLUE-related packages are available
try:
    import transformers, datasets, evaluate, accelerate
    from transformers import DataCollatorWithPadding
    
    print("✓ GLUE benchmark packages available")
    print(f"  transformers: {transformers.__version__}")
    print(f"  datasets: {datasets.__version__}")
    print(f"  evaluate: {evaluate.__version__}")
    print(f"  accelerate: {accelerate.__version__}")
except ImportError as e:
    print(f"Missing package: {e}")
    print("Run: pip install datasets evaluate accelerate")

# Check if jiant is available (optional)
try:
    import jiant
    print(f"✓ jiant available: {jiant.__version__}")
except ImportError:
    print("jiant not installed (optional for advanced GLUE benchmarking, not used in current version)")
    print("Install with: pip install jiant")

# %%
# %pip install tf-keras

# %% [markdown]
# ## Optional: Other Tools
#
# ### jiant for GLUE Benchmarking
#
# jiant is used by authors of the Paper. Tool with utilities fro advanced GLUE benchmarking.
#
# ```bash
# pip install jiant
# ```
#
# jiant provides:
# - Unified interface for GLUE tasks
# - Built-in dataset caching
# - Advanced data augmentation
# - Multi-task learning support
# - Comprehensive evaluation utilities
#
# NOT used for this reproduction study.
